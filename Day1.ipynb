# %%
print("Hello World")
# Out:
# Hello World

# %%
import sys
print("Hello World")
# Out:
# Hello World

# %%
print("Hello, I am Accha Baccha Raj")
# Out:
# Hello, I am Accha Baccha Raj

# %%
i = 10
j = i + 7
print(id(i))
print(id(j))
# Out:
# 2540930886224
# 2540930886448

# %%
x = 4
y = x
print(y)
print(x)
# Out:
# 4
# 4

# %%
x = 10
y = 20
x, y = y, x
print(x, y)
# Out:
# 20 10

# %%
import sys
print(sys.version)
# Out:
# 3.9.13 (tags/v3.9.13:6de2ca5, May 17 2022, 16:36:42) [MSC v.1929 64 bit (AMD64)]
