# %%
print(type(7))
# Out:
# <class 'int'>

# %%
print(type(0o2))
# Out:
# <class 'int'>

# %%
complex(3,4)
# Out:
# (3+4j)

# %%
c = 3 + 8j
print(c.real)
print(c.imag)
# Out:
# 3.0
# 8.0

# %%
print(bool(1))
# Out:
# True

# %%
print(bool("This is not a string"))
# Out:
# True

# %%
print(type(None))
# Out:
# <class 'NoneType'>

# %%
print("Hello " * 5)
# Out:
# Hello Hello Hello Hello Hello

# %%
print(len("Ansh Raj"))
# Out:
# 8

# %%
print(max("Ansh Raj"))
# Out:
# s

# %%
print(min("Ansh Raj"))

# %%
print(sorted("Ansh Raj"))
# Out:
# [' ', 'A', 'R', 'a', 'h', 'j', 'n', 's']

# %%
print(reversed("Ansh Raj"))

# %%
print(''.join(reversed("Ansh Raj")))
# Out:
# jaR hsnA
