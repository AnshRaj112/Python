# %%
print(3+4)
# Out:
# 7

# %%
print(3**4)
# Out:
# 81

# %%
print(6//4)
# Out:
# 1

# %%
print(9//4)
# Out:
# 2

# %%
print(9/4)
# Out:
# 2.25

# %%
f = 4.0
d = 3.0
v = (((f+d)+ 3 ) // 4)
print(v)
print(type(v))
# Out:
# 2.0
# <class 'float'>

# %%
bool(0)
# Out:
# False

# %%
bool(2345)
# Out:
# True

# %%
True and False
# Out:
# False

# %%
not False
# Out:
# True

# %%
not True
# Out:
# False

# %%
True or False
# Out:
# True

# %%
"Time" == "Minute"
# Out:
# False

# %%
7 < 9
# Out:
# True

# %%
7 >= 9
# Out:
# False

# %%
hour = 7
meeting = hour > 12
meeting
# Out:
# False

# %%
a = 10 & 9
print(a)
# Out:
# 8

# %%
a = 10 | 9
print(a)
# Out:
# 11

# %%
print(~10)
# Out:
# -11

# %%
print(not 10)
# Out:
# False

# %%
print(15 >> 2)
# Out:
# 3

# %%
print(bin(15))
# Out:
# 0b1111

# %%
print(bin(3))
# Out:
# 0b11

# %%
print(15 << 2)
# Out:
# 60

# %%
print(bin(60))
# Out:
# 0b111100
